# %% [markdown]
# <a href="https://colab.research.google.com/github/datadigger01/Datahandling/blob/main/week02_pandas_basics1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
[2주차] pandas DataFrame, indexing, filtering, dtype
"""
import pandas as pd
import numpy as np

# 실습용 무역 데이터 생성
np.random.seed(42)
df = pd.DataFrame({
    "country": ["Korea", "Japan", "China", "USA", "Germany"] * 3,
    "year": np.repeat([2022, 2023, 2024], 5),
    "export": np.random.randint(100, 1000, 15).astype(float),
    "import_": np.random.randint(100, 1000, 15).astype(float),
    "region": (["Asia", "Asia", "Asia", "America", "Europe"] * 3),
})

# %%
df.head()
# df.tail()
# df.info()
# Out:
#    country  year  export  import_   region
# 0    Korea  2022   202.0    472.0     Asia
# 1    Japan  2022   535.0    199.0     Asia
# 2    China  2022   960.0    971.0     Asia
# 3      USA  2022   370.0    763.0  America
# 4  Germany  2022   206.0    230.0   Europe

# %%
# ------------------------------------------------------------
# 1. 데이터 구조 파악: 분석의 첫 습관
# ------------------------------------------------------------
print(df.head())
print("\nshape:", df.shape)
print("\ndtypes:\n", df.dtypes)
print("\ninfo:"); df.info()
# Out:
#    country  year  export  import_   region
# 0    Korea  2022   202.0    472.0     Asia
# 1    Japan  2022   535.0    199.0     Asia
# 2    China  2022   960.0    971.0     Asia
# 3      USA  2022   370.0    763.0  America
# 4  Germany  2022   206.0    230.0   Europe
#
# shape: (15, 5)
#
# dtypes:
#  country     object
# year         int64
# export     float64
# import_    float64
# region      object
# dtype: object
#
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  15 non-null     object
#  1   year     15 non-null     int64
#  2   export   15 non-null     float64
#  3   import_  15 non-null     float64
#  4   region   15 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 732.0+ bytes

# %%
# ------------------------------------------------------------
# 2. Indexing: loc(라벨) vs iloc(위치)
# ------------------------------------------------------------
print("\nloc  예시:\n", df.loc[0:2, ["country", "export"]])
print("\niloc 예시:\n", df.iloc[0:3, 0:3])
# Out:
# loc  예시:
#    country  export
# 0   Korea   202.0
# 1   Japan   535.0
# 2   China   960.0
#
# iloc 예시:
#    country  year  export
# 0   Korea  2022   202.0
# 1   Japan  2022   535.0
# 2   China  2022   960.0

# %%
# df['year']
# df["export"]

# %%
# ------------------------------------------------------------
# 3. Filtering (Boolean indexing)
# ------------------------------------------------------------
cond = (df["year"] == 2024) & (df["export"] > 400)
print("\n2024년 수출 400 초과:\n", df[cond])

# query() 방식도 함께
print("\nquery 방식:\n", df.query("year == 2024 and export > 400"))
# Out:
# 2024년 수출 400 초과:
#     country  year  export  import_   region
# 10   Korea  2024   566.0    513.0     Asia
# 12   China  2024   430.0    485.0     Asia
# 13     USA  2024   558.0    291.0  America
#
# query 방식:
#     country  year  export  import_   region
# 10   Korea  2024   566.0    513.0     Asia
# 12   China  2024   430.0    485.0     Asia
# 13     USA  2024   558.0    291.0  America

# %%
# print("\n cond 결과값 \n", cond)

# %%
# ------------------------------------------------------------
# 4. 파생변수 생성과 dtype 관리
# ------------------------------------------------------------
df["trade_balance"] = df["export"] - df["import_"]
df["region"] = df["region"].astype("category")   # 메모리 절약 + 범주형 명시
df["year"] = df["year"].astype("int16")
print("\ndtype 변경 후:\n", df.dtypes)
# Out:
# dtype 변경 후:
#  country            object
# year                int16
# export            float64
# import_           float64
# region           category
# trade_balance     float64
# dtype: object

# %%
# ------------------------------------------------------------
# 5. groupby 기초
# ------------------------------------------------------------
print("\n국가별 평균 수출:\n", df.groupby("country", observed=True)["export"].mean())
print("\n지역-연도별 수출 합계:\n",
      df.groupby(["region", "year"], observed=True)["export"].sum())
# Out:
# 국가별 평균 수출:
#  country
# China      503.333333
# Germany    204.666667
# Japan      549.666667
# Korea      313.000000
# USA        547.333333
# Name: export, dtype: float64
#
# 지역-연도별 수출 합계:
#  region   year
# America  2022     370.0
#          2023     714.0
#          2024     558.0
# Asia     2022    1697.0
#          2023    1091.0
#          2024    1310.0
# Europe   2022     206.0
#          2023     221.0
#          2024     187.0
# Name: export, dtype: float64

# %%
# df.groupby(["region"], observed=True)["export"].mean()

# %% [markdown]
# #### 데이터파일 읽어오기

# %%
df_1=pd.read_csv('/content/drive/MyDrive/데이터처리실무/Data/Agent_Attrition.csv')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AgentID           2401 non-null   int64
#  1   Tgt_3YN           2401 non-null   int64
#  2   Age_Grp           2401 non-null   object
#  3   Gender            2401 non-null   int64
#  4   Apply_CH          2401 non-null   object
#  5   re_hire_freq_grp  2401 non-null   object
#  6   Q2                2401 non-null   int64
#  7   Q7                2401 non-null   int64
#  8   Q8                2401 non-null   int64
#  9   Q18               2401 non-null   int64
#  10  Q22               2401 non-null   int64
#  11  Q38               2401 non-null   int64
#  12  rank_INDEX14      2373 non-null   float64
#  13  rank_INDEX18      2373 non-null   float64
#  14  rank_INDEX23      2373 non-null   float64
#  15  rank_INDEX27      2373 non-null   float64
#  16  rank_INDEX28      2373 non-null   float64
#  17  rank_INDEX29      2373 non-null   float64
#  18  rank_INDEX32      2373 non-null   float64
#  19  rank_INDEX44      2373 non-null   float64
#  20  rank_INDEX93      2373 non-null   float64
#  21  rank_AVG_AMT_6M   2401 non-null   int64
# dtypes: float64(9), int64(10), object(3)
# memory usage: 412.8+ KB

# %%
print(df_1["Age_Grp"].iloc[1])
print(df_1["Age_Grp"].iloc[1:5])
print(df_1.iloc[5:10])

# print("2번째행 출력: \n", df_1["Age_Grp"].iloc[1])
# print("\n 2번째행에서 6번째행까지 출력: \n",df_1["Age_Grp"].iloc[1:5])
# print("\n 6번째행~11번째행까지 출력: \n",df_1.iloc[5:10])
# Out:
# 40G
# 1    40G
# 2    40G
# 3    40G
# 4    40G
# Name: Age_Grp, dtype: object
#    AgentID  Tgt_3YN Age_Grp  Gender Apply_CH re_hire_freq_grp  Q2  Q7  Q8  \
# 5        6        0   5060G       2      MGM                2   4   2   3
# 6        7        0     40G       2      MGM               4~   2   2   5
# 7        8        0   5060G       2      MGM                1   3   3   4
# 8        9        0   5060G       2      MGM               4~   1   2   4
# 9       10        1   5060G       2      MGM                1   2   2   6
#
#    Q18  ...  rank_INDEX14  rank_INDEX18  rank_INDEX23  rank_INDEX27  \
# 5    2  ...           1.0           1.0           2.0           2.0
# 6    2  ...           2.0           2.0           1.0           2.0
# 7    2  ...           1.0           0.0           0.0           2.0
# 8    1  ...           1.0           1.0           2.0           1.0
# 9    1  ...           0.0           3.0           3.0           3.0
#
#    rank_INDEX28  rank_INDEX29  rank_INDEX32  rank_INDEX44  rank_INDEX93  \
# 5           2.0           3.0           0.0           1.0           2.0
# 6           2.0           2.0           2.0           2.0           1.0
# 7           2.0           2.0           0.0           0.0           0.0
# 8           2.0           2.0           1.0           1.0           2.0
# 9           3.0           1.0           3.0           3.0           3.0
#
#    rank_AVG_AMT_6M
# 5                3
# 6                5
# 7                7
# 8                7
# 9                2
#
# [5 rows x 22 columns]

# %%
df_1.describe()
# print(df_1.describe(include="all"))
# print(df_1.describe(exclude=["O"])) # to exclude non-numerical values
# Out:
#            AgentID      Tgt_3YN       Gender           Q2           Q7  \
# count  2401.000000  2401.000000  2401.000000  2401.000000  2401.000000
# mean   1201.000000     0.243232     1.860058     2.645564     2.076218
# std     693.253321     0.429123     0.346999     1.033476     0.946716
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%     601.000000     0.000000     2.000000     2.000000     1.000000
# 50%    1201.000000     0.000000     2.000000     3.000000     2.000000
# 75%    1801.000000     0.000000     2.000000     3.000000     2.000000
# max    2401.000000     1.000000     2.000000     5.000000     5.000000
#
#                 Q8          Q18          Q22          Q38  rank_INDEX14  \
# count  2401.000000  2401.000000  2401.000000  2401.000000   2373.000000
# mean      4.462307     1.816327     3.392753     1.424823      1.543194
# std       1.434811     0.819553     2.178745     0.494419      0.970653
# min       1.000000     1.000000     1.000000     1.000000      0.000000
# 25%       3.000000     1.000000     1.000000     1.000000      1.000000
# 50%       4.000000     2.000000     3.000000     1.000000      2.000000
# 75%       5.000000     2.000000     6.000000     2.000000      2.000000
# max       7.000000     4.000000     6.000000     2.000000      3.000000
#
#        rank_INDEX18  rank_INDEX23  rank_INDEX27  rank_INDEX28  rank_INDEX29  \
# count   2373.000000   2373.000000   2373.000000   2373.000000   2373.000000
# mean       1.507375      1.500211      1.491361      1.500632      1.579857
# std        1.155148      1.118081      1.073024      1.117704      1.158610
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000      1.000000      0.000000
# 50%        1.000000      2.000000      2.000000      2.000000      2.000000
# 75%        3.000000      2.000000      2.000000      2.000000      3.000000
# max        3.000000      3.000000      3.000000      3.000000      3.000000
#
#        rank_INDEX32  rank_INDEX44  rank_INDEX93  rank_AVG_AMT_6M
# count   2373.000000   2373.000000   2373.000000      2401.000000
# mean       1.444585      1.500211      1.578171         5.706372
# std        1.212283      1.118081      1.113452         2.627102
# min        0.000000      0.000000      0.000000         0.000000
# 25%        0.000000      1.000000      1.000000         4.000000
# 50%        1.000000      2.000000      2.000000         6.000000
# 75%        3.000000      2.000000      3.000000         8.000000
# max        3.000000      3.000000      3.000000         9.000000

# %%
df_1.isnull()
# df_1.isnull().sum()
# Out:
#       AgentID  Tgt_3YN  Age_Grp  Gender  Apply_CH  re_hire_freq_grp     Q2  \
# 0       False    False    False   False     False             False  False
# 1       False    False    False   False     False             False  False
# 2       False    False    False   False     False             False  False
# 3       False    False    False   False     False             False  False
# 4       False    False    False   False     False             False  False
# ...       ...      ...      ...     ...       ...               ...    ...
# 2396    False    False    False   False     False             False  False
# 2397    False    False    False   False     False             False  False
# 2398    False    False    False   False     False             False  False
# 2399    False    False    False   False     False             False  False
# 2400    False    False    False   False     False             False  False
#
#          Q7     Q8    Q18  ...  rank_INDEX14  rank_INDEX18  rank_INDEX23  \
# 0     False  False  False  ...         False         False         False
# 1     False  False  False  ...         False         False         False
# 2     False  False  False  ...         False         False         False
# 3     False  False  False  ...         False         False         False
# 4     False  False  False  ...         False         False         False
# ...     ...    ...    ...  ...           ...           ...           ...
# 2396  False  False  False  ...         False         False         False
# 2397  False  False  False  ...         False         False         False
# 2398  False  False  False  ...         False         False         False
# 2399  False  False  False  ...         False         False         False
# 2400  False  False  False  ...         False         False         False
#
#       rank_INDEX27  rank_INDEX28  rank_INDEX29  rank_INDEX32  rank_INDEX44  \
# 0            False         False         False         False         False
# 1            False         False         False         False         False
# 2            False         False         False         False         False
# 3            False         False         False         False         False
# 4            False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 2396         False         False         False         False         False
# 2397         False         False         False         False         False
# 2398         False         False         False         False         False
# 2399         False         False         False         False         False
# 2400         False         False         False         False         False
#
#       rank_INDEX93  rank_AVG_AMT_6M
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
# ...            ...              ...
# 2396         False            False
# 2397         False            False
# 2398         False            False
# 2399         False            False
# 2400         False            False
#
# [2401 rows x 22 columns]

# %% [markdown]
# - url 에서 직접 불러오기

# %%
# pd.read_csv("https://github.com/datadigger01/datamining/blob/main/DATA/SeoulBikeData.csv")
df_2 = pd.read_csv("https://raw.githubusercontent.com/datadigger01/datamining/main/DATA/SeoulBikeData.csv", encoding='cp949')
df_2
# Out:
#             Date  Rented Bike Count  Hour  Temperature(캜)  Humidity(%)  \
# 0     01/12/2017                254     0            -5.2           37
# 1     01/12/2017                204     1            -5.5           38
# 2     01/12/2017                173     2            -6.0           39
# 3     01/12/2017                107     3            -6.2           40
# 4     01/12/2017                 78     4            -6.0           36
# ...          ...                ...   ...             ...          ...
# 8755  30/11/2018               1003    19             4.2           34
# 8756  30/11/2018                764    20             3.4           37
# 8757  30/11/2018                694    21             2.6           39
# 8758  30/11/2018                712    22             2.1           41
# 8759  30/11/2018                584    23             1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(캜)  \
# 0                  2.2              2000                     -17.6
# 1                  0.8              2000                     -17.6
# 2                  1.0              2000                     -17.7
# 3                  0.9              2000                     -17.6
# 4                  2.3              2000                     -18.6
# ...                ...               ...                       ...
# 8755               2.6              1894                     -10.3
# 8756               2.3              2000                      -9.9
# 8757               0.3              1968                      -9.9
# 8758               1.0              1859                      -9.8
# 8759               1.3              1909                      -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                         0.0           0.0            0.0  Winter
# 1                         0.0           0.0            0.0  Winter
# 2                         0.0           0.0            0.0  Winter
# 3                         0.0           0.0            0.0  Winter
# 4                         0.0           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 8755                      0.0           0.0            0.0  Autumn
# 8756                      0.0           0.0            0.0  Autumn
# 8757                      0.0           0.0            0.0  Autumn
# 8758                      0.0           0.0            0.0  Autumn
# 8759                      0.0           0.0            0.0  Autumn
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 1     No Holiday             Yes
# 2     No Holiday             Yes
# 3     No Holiday             Yes
# 4     No Holiday             Yes
# ...          ...             ...
# 8755  No Holiday             Yes
# 8756  No Holiday             Yes
# 8757  No Holiday             Yes
# 8758  No Holiday             Yes
# 8759  No Holiday             Yes
#
# [8760 rows x 14 columns]

# %%
df_2.info()
df_2.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8760 non-null   object
#  1   Rented Bike Count         8760 non-null   int64
#  2   Hour                      8760 non-null   int64
#  3   Temperature(캜)            8760 non-null   float64
#  4   Humidity(%)               8760 non-null   int64
#  5   Wind speed (m/s)          8760 non-null   float64
#  6   Visibility (10m)          8760 non-null   int64
#  7   Dew point temperature(캜)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)   8760 non-null   float64
#  9   Rainfall(mm)              8760 non-null   float64
#  10  Snowfall (cm)             8760 non-null   float64
#  11  Seasons                   8760 non-null   object
#  12  Holiday                   8760 non-null   object
#  13  Functioning Day           8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.3+ KB
# Date                         object
# Rented Bike Count             int64
# Hour                          int64
# Temperature(캜)              float64
# Humidity(%)                   int64
# Wind speed (m/s)            float64
# Visibility (10m)              int64
# Dew point temperature(캜)    float64
# Solar Radiation (MJ/m2)     float64
# Rainfall(mm)                float64
# Snowfall (cm)               float64
# Seasons                      object
# Holiday                      object
# Functioning Day              object
# dtype: object

# %% [markdown]
# #### 1. 컬럼명을 적절하게 변환(AI활용)

# %%
import re

def clean_column_names(df):
    cols = df.columns
    new_cols = []
    for col in cols:
        # Convert to lowercase
        new_col = col.lower()
        # Replace spaces with underscores
        new_col = new_col.replace(' ', '_')
        # Remove all characters that are not lowercase letters, numbers, or underscores
        new_col = re.sub(r'[^a-z0-9_]', '', new_col)
        new_cols.append(new_col)
    df.columns = new_cols
    return df

df_2 = clean_column_names(df_2)
print("변환된 df_2 컬럼명:")
print(df_2.columns)
# Out:
# 변환된 df_2 컬럼명:
# Index(['date', 'rented_bike_count', 'hour', 'temperature', 'humidity',
#        'wind_speed_ms', 'visibility_10m', 'dew_point_temperature',
#        'solar_radiation_mjm2', 'rainfallmm', 'snowfall_cm', 'seasons',
#        'holiday', 'functioning_day'],
#       dtype='object')

# %% [markdown]
# #### 2. Date 컬럼 타입을 date 타입으로 변환(AI활용)

# %%
df_2['date'] = pd.to_datetime(df_2['date'], format='%d/%m/%Y')
print("변환된 df_2 'date' 컬럼 타입:")
print(df_2['date'].dtypes)
print("변환된 df_2의 첫 5개 행:")
display(df_2.head())
# Out:
# 변환된 df_2 'date' 컬럼 타입:
# datetime64[ns]
# 변환된 df_2의 첫 5개 행:
#         date  rented_bike_count  hour  temperature  humidity  wind_speed_ms  \
# 0 2017-12-01                254     0         -5.2        37            2.2
# 1 2017-12-01                204     1         -5.5        38            0.8
# 2 2017-12-01                173     2         -6.0        39            1.0
# 3 2017-12-01                107     3         -6.2        40            0.9
# 4 2017-12-01                 78     4         -6.0        36            2.3
#
#    visibility_10m  dew_point_temperature  solar_radiation_mjm2  rainfallmm  \
# 0            2000                  -17.6                   0.0         0.0
# 1            2000                  -17.6                   0.0         0.0
# 2            2000                  -17.7                   0.0         0.0
# 3            2000                  -17.6                   0.0         0.0
# 4            2000                  -18.6                   0.0         0.0
#
#    snowfall_cm seasons     holiday functioning_day
# 0          0.0  Winter  No Holiday             Yes
# 1          0.0  Winter  No Holiday             Yes
# 2          0.0  Winter  No Holiday             Yes
# 3          0.0  Winter  No Holiday             Yes
# 4          0.0  Winter  No Holiday             Yes

# %%
print(df_2.dtypes)
print(df_2.info())
# Out:
# date                     datetime64[ns]
# rented_bike_count                 int64
# hour                              int64
# temperature                     float64
# humidity                          int64
# wind_speed_ms                   float64
# visibility_10m                    int64
# dew_point_temperature           float64
# solar_radiation_mjm2            float64
# rainfallmm                      float64
# snowfall_cm                     float64
# seasons                          object
# holiday                          object
# functioning_day                  object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   8760 non-null   datetime64[ns]
#  1   rented_bike_count      8760 non-null   int64
#  2   hour                   8760 non-null   int64
#  3   temperature            8760 non-null   float64
#  4   humidity               8760 non-null   int64
#  5   wind_speed_ms          8760 non-null   float64
#  6   visibility_10m         8760 non-null   int64
#  7   dew_point_temperature  8760 non-null   float64
#  8   solar_radiation_mjm2   8760 non-null   float64
#  9   rainfallmm             8760 non-null   float64
#  10  snowfall_cm            8760 non-null   float64
#  11  seasons                8760 non-null   object
#  12  holiday                8760 non-null   object
#  13  functioning_day        8760 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 958.3+ KB
# None

# %%
df_2
# Out:
#            date  rented_bike_count  hour  temperature  humidity  \
# 0    2017-12-01                254     0         -5.2        37
# 1    2017-12-01                204     1         -5.5        38
# 2    2017-12-01                173     2         -6.0        39
# 3    2017-12-01                107     3         -6.2        40
# 4    2017-12-01                 78     4         -6.0        36
# ...         ...                ...   ...          ...       ...
# 8755 2018-11-30               1003    19          4.2        34
# 8756 2018-11-30                764    20          3.4        37
# 8757 2018-11-30                694    21          2.6        39
# 8758 2018-11-30                712    22          2.1        41
# 8759 2018-11-30                584    23          1.9        43
#
#       wind_speed_ms  visibility_10m  dew_point_temperature  \
# 0               2.2            2000                  -17.6
# 1               0.8            2000                  -17.6
# 2               1.0            2000                  -17.7
# 3               0.9            2000                  -17.6
# 4               2.3            2000                  -18.6
# ...             ...             ...                    ...
# 8755            2.6            1894                  -10.3
# 8756            2.3            2000                   -9.9
# 8757            0.3            1968                   -9.9
# 8758            1.0            1859                   -9.8
# 8759            1.3            1909                   -9.3
#
#       solar_radiation_mjm2  rainfallmm  snowfall_cm seasons     holiday  \
# 0                      0.0         0.0          0.0  Winter  No Holiday
# 1                      0.0         0.0          0.0  Winter  No Holiday
# 2                      0.0         0.0          0.0  Winter  No Holiday
# 3                      0.0         0.0          0.0  Winter  No Holiday
# 4                      0.0         0.0          0.0  Winter  No Holiday
# ...                    ...         ...          ...     ...         ...
# 8755                   0.0         0.0          0.0  Autumn  No Holiday
# 8756                   0.0         0.0          0.0  Autumn  No Holiday
# 8757                   0.0         0.0          0.0  Autumn  No Holiday
# 8758                   0.0         0.0          0.0  Autumn  No Holiday
# 8759                   0.0         0.0          0.0  Autumn  No Holiday
#
#      functioning_day
# 0                Yes
# 1                Yes
# 2                Yes
# 3                Yes
# 4                Yes
# ...              ...
# 8755             Yes
# 8756             Yes
# 8757             Yes
# 8758             Yes
# 8759             Yes
#
# [8760 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 7))
sns.lineplot(x='date', y='rented_bike_count', data=df_2)
plt.title('Daily Rented Bike Count Over Time')
plt.xlabel('Date')
plt.ylabel('Rented Bike Count')
plt.grid(True)
plt.show()
